# %% [markdown]
# # Execute the below query in Microsoft SQL Server management

# %% [markdown]
# Data: Develop your a data analysis project that you can add to your portfolio. Beginners are welcome. You will be performing the following actions.

# %% [markdown]
# 1. Build a Database
# 2. Analyze and Retrieve Data with SQL
# 3. Connect Power BI to a Database
# 4. Visualize Data in Power BI

# %% [markdown]
# Find the dataset here:
# https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqa01EMEZIcVhEbExtajFPSDhSTWJlMDFOMmFzd3xBQ3Jtc0tubFY1S2VUZms4aHdXcHdqSVNkVlhwX1JaSmFDTnNUQzNRbW9jSWUxa0ZweGUza2E4aTFTNDZfd2JjdU04SkwzZGl0M082OGo1NnYtR1ZMSmxKdkVrSVZnVUtXVk05VG9fOFN6cFBiM08taUxZY1c3NA&q=https%3A%2F%2Fwww.absentdata.com%2Fhotel_revenue_historical_full%2F&v=S2zBHmkRbhY
#
# You can download Microsoft SQL Server Studio:
# https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqbVhrZzNDYk95bXQ3VWtJSDloWkd3aWhmb3hZQXxBQ3Jtc0tsNlloS05LZGRwSk85TElkWl81b3FXR21vUkZ1VnI5MjBMdGNiQzVUVDJaMFNfRXU4VmF1TWVLNHRHX0tNS3RMRFFpODVGV3pzYUFGMEpXWlA4WTIwSTN4Ul8yUHJxSzYxeFhlRF8tWHdMX1hBY0NsOA&q=https%3A%2F%2Fdocs.microsoft.com%2Fen-us%2Fsql%2Fssms%2Fdownload-sql-server-management-studio-ssms%3Fview%3Dsql-server-ver15&v=S2zBHmkRbhY

# %% [markdown]
# Run the below in SQL server after uploading the excel files

# %% [markdown]
# with hotels as (
# select * from dbo.['2018$']
# union
# select * from dbo.['2019$']
# union
# select * from dbo.['2020$'])
#
# select * from hotels
# left join dbo.market_segment$
# on hotels.market_segment = market_segment$.market_segment
# left join
# dbo.meal_cost$
# on meal_cost$.meal = hotels.meal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Powerbi

# %% [markdown]
# Create new variables Revenue

# %%
Revenue= (([stays_in_week_nights] + [stays_in_weekend_nights])) + ([adr] * [Discount])

# %% [markdown]
# Create interactive dashboards with discounts, revenuem, adr and time series analysis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  # 1. "Is our hotel revenue growing by year?"
#  We have two hotel types so it
#  would be good to segment
#  revenue by hotel type.

# %% [markdown]
# ### Answer:
# Revenue is growing however, There is a drop in revenue for 2020. It could be because of incomplete data

# %% [markdown]
# # 2. "Should we increase our  parking lot size?
#  We want to understand If there is
#  a trend is guest with personal
#  cars.

# %% [markdown]
# ### Answer:
# Parking percentage always lies in 2.5%. This point we don't need to maximize the parking lot

# %% [markdown]
# # 3. "What trends can we see in  the data?"
#  Focus on average daily rate and
#  guests to explore seasonality

# %% [markdown]
# ### Answer:
# City hotel is generating more revenue when compared to resorts
